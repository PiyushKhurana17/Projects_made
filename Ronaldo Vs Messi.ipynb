# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
import random
M=pd.read_csv('Downloads\\Ronaldo vs Messi\\Messi.csv')
R=pd.read_csv('Downloads\\Ronaldo vs Messi\\Ronaldo.csv')

print('Heya! This is Leonaldo. My programmers have designed me such that I can show you the great legacy embarked')
print('by The Great Lionel Messi and The Great Cristiano Ronaldo')
arg1=input('Enter whose stat you want to see,R for Ronaldo, M for Messi and C if you want to compare their stats: ')
print(arg1)
print('')
if arg1=='R' or arg1=='r':
    # Read Images
    image_path = "Downloads\\Ronaldo vs Messi\\CR7.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
    print('Suiiiiiii!')
    print('')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Goals,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Goals')
    plt.title('Goals Per Year Scored By Ronaldo')
    plt.show()
    print('Suiiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Assists,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Assists')
    plt.title('Assists Per Year By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Appearance,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Appearance')
    plt.title('Appearances Per Year Made By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Key_Passes,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Key_passes')
    plt.title('Key Passes Per Made By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Free_Kicks,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Free_kicks')
    plt.title('Free Kicks Per Year Scored By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Hat_tricks,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Hat_tricks')
    plt.title('HatTricks Per Year Scored By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Penalties,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Penalties')
    plt.title('Penalties Per Year Scored By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Successful_Dribbles,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Successful_dribbles')
    plt.title('Successful Dribbles Per Year Made By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Man_of_the_Match,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('No. of times Man of the match')
    plt.title('Man Of Matches Won by Ronaldo Per Year')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Conversion_Penalties,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Penalty conversion %')
    plt.title('Penalties Conversion Per Year By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,R.Shots_per_goal,color=['y','b'])
    plt.xlabel('Year')
    plt.ylabel('Shots/goal')
    plt.title('Shots per Goal By Ronaldo')
    plt.show()
    print('suiiiiiii!')
    
    
    
    
elif arg1=='M' or arg1=='m':
    # Read Images
    image_path = "Downloads\\Ronaldo vs Messi\\LM10.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
    print('Ankara Messi')
    print('')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Goals,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Goals')
    plt.title('Goals Per Year Scored By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Assists,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Assits')
    plt.title('Assists Per Year By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Appearance,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Apperance')
    plt.title('Appearances Per Year Made By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Key_Passes,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Key_Passes')
    plt.title('Key Passes Per Made By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Free_Kicks,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Free_kicks')
    plt.title('Free Kicks Per Year Scored By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Hat_Tricks,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Hat_Tricks')
    plt.title('HatTricks Per Year Scored By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Penalties,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Penalties')
    plt.title('Penalties Per Year Scored By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Successful_Dribbles,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Successful_Dribbles')
    plt.title('Successful Dribbles Per Year Made By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Man_of_the_Match,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('No. of times Man of the match')
    plt.title('Man Of Matches Won by Messi Per Year')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Conversion_Penalties,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Conversion % Penalties')
    plt.title('Penalties Conversion Per Year By Messi')
    plt.show()
    print('Ankara Messi!')
    
    plt.figure(figsize=(25,5))
    plt.bar(M.Year,M.Shots_per_goal,color=['pink','k'])
    plt.xlabel('Year')
    plt.ylabel('Shots/goal ')
    plt.title('Shots per Goal By Messi')
    plt.show()
    print('Ankara Messi!')
    
elif arg1=='C' or arg1=='c':
    # Read Images
    image_path = "Downloads/Ronaldo vs Messi/CRLM710.webp" 
    img = mpimg.imread(image_path)
 
# Output Images
    plt.axis('off')
    plt.imshow(img)
    print('All Hail the Kings!')
    print('')
    
    RG=R['Goals']
    MG=M['Goals']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('Goals Scored')
    plt.legend()
    plt.title('Comparison Of Goals Scored Between GOATS')
    plt.show()
    
    RG=R['Assists']
    MG=M['Assists']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('Assists Given')
    plt.legend()
    plt.title('Comparison Of Assists Between GOATS')
    plt.show()
    
    RG=R['Appearance']
    MG=M['Appearance']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('No. Of Games Appeared')
    plt.legend()
    plt.title('Comparison Of No. of Games Appeared Between GOATS')
    plt.show()
    
    RG=R['Key_Passes']
    MG=M['Key_Passes']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('Key Passes')
    plt.legend()
    plt.title('Comparison Of Key Passes Between GOATS')
    plt.show()
    
    RG=R['Free_Kicks']
    MG=M['Free_Kicks']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('FreeKicks Scored')
    plt.legend()
    plt.title('Comparison Of FreeKicks Scored Between GOATS')
    plt.show()
    
    RG=R['Hat_tricks']
    MG=M['Hat_Tricks']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('HatTricks Scored')
    plt.legend()
    plt.title('Comparison Of HatTricks scored Between GOATS')
    plt.show()
    
    RG=R['Penalties']
    MG=M['Penalties']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('Penalties Scored')
    plt.legend()
    plt.title('Comparison Of Penalties Scored Between GOATS')
    plt.show()
    
    RG=R['Successful_Dribbles']
    MG=M['Successful_Dribbles']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('Succesful Dribbles')
    plt.legend()
    plt.title('Comparison Of Successful Dribbles Between GOATS')
    plt.show()
    
    RG=R['Man_of_the_Match']
    MG=M['Man_of_the_Match']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('Man Of The Match Awards')
    plt.legend()
    plt.title('Comparison Of MOMs Between GOATS')
    plt.show()
    
    RG=R['Conversion_Penalties']
    MG=M['Conversion_Penalties']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('Penalty Conversion Success')
    plt.legend()
    plt.title('Comparison Of Penalty Conversion Between GOATS')
    plt.show()
    
    RG=R['Shots_per_goal']
    MG=M['Shots_per_goal']
    x=np.arange(len(RG))
    plt.figure(figsize=(25,5))
    plt.bar(R.Year,RG,color='yellow',width=0.3,label='Ronaldo')
    plt.bar(x+0.3,MG,color='pink',width=0.3,label='Messi')
    plt.xlabel('Year')
    plt.ylabel('Shots Per Goal')
    plt.legend()
    plt.title('Comparison Of Shots Per Goal Between GOATS')
    plt.show()
    
    t=[4,5]
    n=['Messi','Ronaldo']
    plt.title('Champions League Trophy')
    plt.pie(t, labels=n,colors=('pink','yellow'),autopct="%2.2f%%")
    plt.show()
    
    t=[12,7]
    n=['Messi','Ronaldo']
    plt.title('League Trophies')
    plt.pie(t, labels=n,colors=('pink','yellow'),autopct="%2.2f%%")
    plt.show()
    
    t=[7,6]
    n=['Messi','Ronaldo']
    plt.title('Domestic Cups')
    plt.pie(t, labels=n,colors=('pink','yellow'),autopct="%2.2f%%")
    plt.show()
    
    t=[9,7]
    n=['Messi','Ronaldo']
    plt.title('Domestic Super Cups')
    plt.pie(t, labels=n,colors=('pink','yellow'),autopct="%2.2f%%")
    plt.show()
    
    t=[3,3]
    n=['Messi','Ronaldo']
    plt.title('UEFA Super Cup')
    plt.pie(t, labels=n,colors=('pink','yellow'),autopct="%2.2f%%")
    plt.show()
    
    t=[3,4]
    n=['Messi','Ronaldo']
    plt.title('Club World Cup')
    plt.pie(t, labels=n,colors=('pink','yellow'),autopct="%2.2f%%")
    plt.show()
    
    t=[8,5]
    n=['Messi','Ronaldo']
    plt.title("Ballon D'oR")
    plt.pie(t, labels=n,colors=('yellow','black'),autopct="%2.2f%%")
    plt.show()
    
    t=[7,5]
    n=['Messi','Ronaldo']
    plt.title('Fifa World Player Of The Year')
    plt.pie(t, labels=n,colors=('yellow','black'),autopct="%2.2f%%")
    plt.show()
    
    t=[6,4]
    n=['Messi','Ronaldo']
    plt.title('European Golden Shoe')
    plt.pie(t, labels=n,colors=('yellow','black'),autopct="%2.2f%%")
    plt.show()
    
    
else:
    print('No results to show....')
print('')    
print('So Who Do You Think Has Ignited this Rivalry')
print('What really made this rivalry catch fire was their incredible, unprecedented goalscoring rates, ')
print('with both Messi and Ronaldo averaging more than one goal every game at their peaks. During the 9 years')
print('Ronaldo spent at Real Madrid, Messi and Ronaldo both scored a goal every 85 minutes in all competitions. ')
print('The adjacency of their goalscoring - matching each other blow for blow - has been astounding over the years.')
print(" ")
print('Over their entire careers, its Messi who edges the ratio, with 0.78 goals per game, whereas Ronaldo has scored')
print('0.72 goals per game. If we drill down into goals per minutes, Messi scores a goal every 105 minutes, and Ronaldo')
print('scores a goal every 112 minutes.')
print('')
print('Ronaldo still has more all time career goals than Messi though (Ronaldo has 869 career goals and Messi has 821 career')
print('goals), but Ronaldo has played 154 more games over his career than Messi has.')
print('')
print('Although Messi shades the overall ratio, Ronaldo spent more of his formative years as a more traditional right winger,')
print('only really starting to focus on goalscoring as his primary function in 2006, 3-4 years into his career. For Messi, ')
print('it was 2-3 years until he completed the transformation from a nippy winger into a player hungry for goals above') 
print('everything else. If we take these differing beginnings into account, the ratios would be even closer.')

print('Of all the categories, goalscoring is the hardest to separate them on.')
print('')
print('')
print("No other footballers in history have sustained such elite levels for such a long period of time. Their stranglehold")
print("on the coveted Ballon dOr award has been relentless, with Messi's 8 Ballon dOr trophies edging Ronaldo's haul of 5 ")
print("Ballons dOr. No other player in history has won more than 3! If Messi or Ronaldo didn't have each other to compete ")
print("with for the award over the years, its not inconceivable that one of them could have picked up the award 10 times or")
print("more.")
print("In terms of UEFA's top award, it's Ronaldo that has the edge with 4 awards (1x UEFA Club Footballer of the Year,")
print("2x UEFA Best Player in Europe, 1x UEFA Men's Player of the Year) to Messi's 3 awards (1x UEFA Club Footballer of the")
print("Year, 2x UEFA Best Player in Europe).")
print("In terms of golden boots, Messi has finished as the league's top scorer 8 times, winning the European Golden Shoe")
print("on 6 of those occasions. Ronaldo has finished as top scorer in the league 5 times (once in the Premier League, once")
print("in Serie A, and 3 times in La Liga), winning 4 European Golden Shoes in the process.")
print("In terms of golden boots, Messi has finished as the league's top scorer 8 times, winning the European Golden Shoe")
print("on 6 of those occasions. Ronaldo has finished as top scorer in the league 5 times (once in the Premier League, once")
print("in Serie A, and 3 times in La Liga), winning 4 European Golden Shoes in the process.")
print("Messi has however won the Golden Ball, awarded to the player of the tournament at the World Cup, on two occasions") 
print("- once in 2014 when he took his side to the final and again in 2022 where he was triumphant. He has also been named")
print("Copa America's Best Player on two occasions, and Best Young Player once.")
print('')
print('But If I were to Describe Them')
print('')
print('If All the Brilliant Engineers Were to Come up with The Idea of Designing A Football Player they would have ')
print("designed it the Way Ronaldo Is!")
print('But If An Artist Was to come up with The Idea of Making A Footballer It would be Sure Shot Messi!')

print('')
print('')
print('Now Lets Play A Game')
print('')
print('Pick Your 5 A Side Team, You can include Messi and Cristiano Ronaldo as well')
print('')
print('My Pick is Ronaldinho,David Beckham,Samuel Eto,Franz Beckenbaur,David de Gea')
print('')
print('You can take help from the following List of players categorized')
print('')
df=pd.DataFrame({'Attackers':['Ronaldo R9','Neymar','Kylian Mbappe','Erling Haaland','Pele','Diego Maradona'],
                'MidFielders':['Zidane','Jude Bellingham','Luka Modric','Xavi','Iniesta','Bruno Fernandes'],
                'Defenders':['Nesta','Puyol','Paolo Maldini','Sergio Ramos','Virgil Van Dijk','Thiago Silva'],
                'GoalKeepers':['Lev Yashin','Iker Casillas','Alisson','Manuel Neuer','Ederson','Buffon']})
print(df)
print('')
lst=[]
for i in range(0,5):
    arg2=input('Enter Your Player: ')
    lst.append(arg2)

lst2=['Ronaldinho','David Beckham','Samuel Eto','Franz Beckenbaur','David de Gea']    
arg3=input('Enter The Name Of the Coach: ')
arg4=input('Enter Your Team Name: ')
print('Lineups: ')
print('Team- ',arg4)
print('Manager- ',arg3)
print('Players- ',lst[0],',',lst[1],',',lst[2],',',lst[3],',',lst[4])
print('Vs')
print('Team- Leonaldo United')
print('Manager- Leonaldo')
print('Players- Ronaldinho,David Beckham,Samuel Eto,Franz Beckenbaur,David de Gea')
a=np.random.randint(0,10)
b=np.random.randint(0,10)
s=['Old Trafford','Narendra Modi Stadium','Anfield','Bernabeu','Camp Nou','San Siro','Wembley']
c=np.random.randint(0,7)
print('')
print('Stadium: ',s[c])
print('')
if c==0:
    image_path = "Downloads/Ronaldo vs Messi/0.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
elif c==1:
    image_path = "Downloads/Ronaldo vs Messi/1.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
elif c==2:
    image_path = "Downloads/Ronaldo vs Messi/2.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
elif c==3:
    image_path = "Downloads/Ronaldo vs Messi/3.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
elif c==4:
    image_path = "Downloads/Ronaldo vs Messi/4.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
elif c==5:
    image_path = "Downloads/Ronaldo vs Messi/5.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
elif c==6:
    image_path = "Downloads/Ronaldo vs Messi/6.jpg" 
    img = mpimg.imread(image_path)
    plt.axis('off')
    plt.imshow(img)
else:
    print('No Stadium')
    
print('')
print('Scoreline')
print('')
print(a,' - ',b)
print('')
print(arg4,'Score: ',a)
print('Scorers: ')
for x in range(0,a):
    g1=np.random.randint(0,5)
    print(lst[g1])
print('')
print('Leonaldo United Score: ',b)
print('Scorers: ')
for y in range(0,b):
    g2=np.random.randint(0,5)
    print(lst2[g2])
print('')
a1=np.random.randint(0,5)
b1=np.random.randint(0,5)
ab=np.random.randint(0,5)
lt=lst+lst2

if a>b:
    print('Congratulations! You Won the Game')
    print('Man Of The Match Goes To: ',lst[a1],'!')
    
elif a<b:
    print('Better Luck Next Time! ')
    print('Man of The Match Goes To: ',lst2[b1],'!')
    

elif b==a:
    print('Good Game!')
    print('Man Of The Match Goes To: ',lt[ab],'!')
    
else:
    print('Nothin To show')
# Out:
# Heya! This is Leonaldo. My programmers have designed me such that I can show you the great legacy embarked
# by The Great Lionel Messi and The Great Cristiano Ronaldo
# Enter whose stat you want to see,R for Ronaldo, M for Messi and C if you want to compare their stats:  r
# r
#
# Suiiiiiii!
# Suiiiiiiii!
# suiiiiiii!
# suiiiiiii!
# suiiiiiii!
# suiiiiiii!
# suiiiiiii!
# suiiiiiii!
# suiiiiiii!
# suiiiiiii!
# suiiiiiii!
# suiiiiiii!
#
# So Who Do You Think Has Ignited this Rivalry
# What really made this rivalry catch fire was their incredible, unprecedented goalscoring rates,
# with both Messi and Ronaldo averaging more than one goal every game at their peaks. During the 9 years
# Ronaldo spent at Real Madrid, Messi and Ronaldo both scored a goal every 85 minutes in all competitions.
# The adjacency of their goalscoring - matching each other blow for blow - has been astounding over the years.
#
# ...
